# %%
import pandas as pd
import numpy as np
import json

# %%
df = pd.read_excel("../data/crawling_result_with_codenames_nan.xlsx")
df.tail()
# Out:
#              date                      tournament_title  patch  \
# 20064  2021-12-23  \n\t\t\t\t\tVCS 2021 Winter Playoffs  11.24
# 20065  2021-12-22  \n\t\t\t\t\tVCS 2021 Winter Playoffs  11.24
# 20066  2021-12-22  \n\t\t\t\t\tVCS 2021 Winter Playoffs  11.24
# 20067  2021-12-22  \n\t\t\t\t\tVCS 2021 Winter Playoffs  11.24
# 20068  2021-12-22  \n\t\t\t\t\tVCS 2021 Winter Playoffs  11.24
#
#                                  blueteam                             redteam  \
# 20064               Burst The Sky Esports                         GAM Esports
# 20065  CERBERUS Esports (Vietnamese Team)                      Luxury Esports
# 20066                      Luxury Esports  CERBERUS Esports (Vietnamese Team)
# 20067                      Luxury Esports  CERBERUS Esports (Vietnamese Team)
# 20068  CERBERUS Esports (Vietnamese Team)                      Luxury Esports
#
#       winner_side         ban_0     ban_1    ban_2      ban_3  ...  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20069 entries, 0 to 20068
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              20069 non-null  object
#  1   tournament_title  20069 non-null  object
#  2   patch             20069 non-null  object
#  3   blueteam          20069 non-null  object
#  4   redteam           20069 non-null  object
#  5   winner_side       20069 non-null  object
#  6   ban_0             20025 non-null  object
#  7   ban_1             20042 non-null  object
#  8   ban_2             20037 non-null  object
#  9   ban_3             16863 non-null  object
#  10  ban_4             16777 non-null  object
#  11  ban_5             20017 non-null  object
#  12  ban_6             20041 non-null  object
#  13  ban_7             20033 non-null  object
#  14  ban_8             16868 non-null  object
#  15  ban_9             16766 non-null  object
# ...

# %%
blueteam_na = df.loc[df["blueteam_code"].isna()]["blueteam"]
redteam_na = df.loc[df["redteam_code"].isna()]["redteam"]

# %%
na = np.unique(np.concatenate((blueteam_na, redteam_na)))
all = np.unique(np.concatenate((df["blueteam"], df["redteam"])))
print(len(na), len(all))
# Out:
# 128 365
